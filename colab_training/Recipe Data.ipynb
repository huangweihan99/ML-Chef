# %% [markdown]
# # **Milestone 1 - Data Preprocessing**

# %% [markdown]
# ## Importing Libraries and Modules
#
# The cell below contains all imported libraries that are used in this notebook.

# %%
! pip install transformers
import pandas as pd
import re
import numpy as np
import transformers
from ast import literal_eval
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.29.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)

# %% [markdown]
# ## Loading data set
#
# Data set was saved in my Google Drive in a CSV format and was loaded as Pandas DataFrame as shown below:

# %%
dataset_file_path="/content/drive/MyDrive/recipe_data/full_dataset.csv"
df=pd.read_csv(dataset_file_path)
df
# Out:
#          Unnamed: 0                                          title  \
# 0                 0                            No-Bake Nut Cookies
# 1                 1                          Jewell Ball'S Chicken
# 2                 2                                    Creamy Corn
# 3                 3                                  Chicken Funny
# 4                 4                           Reeses Cups(Candy)
# ...             ...                                            ...
# 2231137     2231137                            Sunny's Fake Crepes
# 2231138     2231138                                     Devil Eggs
# 2231139     2231139  Extremely Easy and Quick - Namul Daikon Salad
# 2231140     2231140     Pan-Roasted Pork Chops With Apple Fritters
# 2231141     2231141                 Polpette in Spicy Tomato Sauce
#
#                                                ingredients  \
# 0        ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1        ["1 small jar chipped beef, cut up", "4 boned ...
# 2        ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3        ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4        ["1 c. peanut butter", "3/4 c. graham cracker ...
# ...                                                    ...
# 2231137  ["1/2 cup chocolate hazelnut spread (recommend...
# 2231138  ["1 dozen eggs", "1 paprika", "1 salt and pepp...
# 2231139  ["150 grams Daikon radish", "1 tbsp Sesame oil...
# 2231140  ["1 cup apple cider", "6 tablespoons sugar", "...
# 2231141  ["1 pound ground veal", "1/2 pound sweet Itali...
#
#                                                 directions  \
# 0        ["In a heavy 2-quart saucepan, mix brown sugar...
# 1        ["Place chipped beef on bottom of baking dish....
# 2        ["In a slow cooker, combine all ingredients. C...
# 3        ["Boil and debone chicken.", "Put bite size pi...
# 4        ["Combine first four ingredients and press in ...
# ...                                                    ...
# 2231137  ["Spread hazelnut spread on 1 side of each tor...
# 2231138  ["Boil eggs on medium for 30mins.", "Then cool...
# 2231139  ["Julienne the daikon and squeeze out the exce...
# 2231140  ["In a large bowl, mix the apple cider with 4 ...
# 2231141  ["Preheat the oven to 350.", "In a bowl, mix t...
#
#                                                       link     source  \
# 0           www.cookbooks.com/Recipe-Details.aspx?id=44874   Gathered
# 1          www.cookbooks.com/Recipe-Details.aspx?id=699419   Gathered
# 2           www.cookbooks.com/Recipe-Details.aspx?id=10570   Gathered
# 3          www.cookbooks.com/Recipe-Details.aspx?id=897570   Gathered
# 4          www.cookbooks.com/Recipe-Details.aspx?id=659239   Gathered
# ...                                                    ...        ...
# 2231137  www.foodnetwork.com/recipes/sunny-anderson/sun...  Recipes1M
# 2231138           cookpad.com/us/recipes/355411-devil-eggs  Recipes1M
# 2231139  cookpad.com/us/recipes/153324-extremely-easy-a...  Recipes1M
# 2231140                cooking.nytimes.com/recipes/1015164  Recipes1M
# 2231141  www.foodandwine.com/recipes/polpette-spicy-tom...  Recipes1M
#
#                                                        NER
# 0        ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1        ["beef", "chicken breasts", "cream of mushroom...
# 2        ["frozen corn", "cream cheese", "butter", "gar...
# 3        ["chicken", "chicken gravy", "cream of mushroo...
# 4        ["peanut butter", "graham cracker crumbs", "bu...
# ...                                                    ...
# 2231137  ["chocolate hazelnut spread", "tortillas", "bu...
# 2231138  ["eggs", "paprika", "salt", "choice", "miracle...
# 2231139  ["radish", "Sesame oil", "White sesame seeds",...
# 2231140  ["apple cider", "sugar", "kosher salt", "bay l...
# 2231141  ["ground veal", "sausage", "bread crumbs", "mi...
#
# [2231142 rows x 7 columns]

# %% [markdown]
# There are a total of 2,231,141 recipes. The data type of the ingredients, directions and NER columns aren't arrays of strings despite the square brackets, instead each entry is a single string.

# %% [markdown]
# ## Filtering data set
#
# To ensure that the model is able to generate detailed and precise recipes, the recipes with the following features have to be removed to only leave high quality recipes in the data set:
#
# * Recipes whose source is not "Gathered"
# * Recipes with fewer than 2 ingredients, 2 directions, 2 words in the title, or 25 words in the directions.
# * Recipes that enumerate steps in the directions, as they over-complicates the structure of a recipe and may hinder the learning process. These recipes can be detected by filtering out recipes that contain the word "step" in the directions, indicating that enumerated steps were cross-referenced.
# * Recipes with the phrase "mix all", the model should be able to generate detailed recipes with explicit directions.

# %%
# returns an array of boolean values that is then applied to the dataframe to filter out certain rows
gathered_filter = (df.source == 'Gathered')
filtered_df = df[gathered_filter]
filtered_df
# Out:
#          Unnamed: 0                                title  \
# 0                 0                  No-Bake Nut Cookies
# 1                 1                Jewell Ball'S Chicken
# 2                 2                          Creamy Corn
# 3                 3                        Chicken Funny
# 4                 4                 Reeses Cups(Candy)
# ...             ...                                  ...
# 1643093     1643093           Tuna 'N Egg Salad In Pitas
# 1643094     1643094               Croque Monsieur Panini
# 1643095     1643095  Croque Monsieur With Cucumber Salad
# 1643096     1643096                     Baked Pork Chops
# 1643097     1643097          Date Filled Oatmeal Cookies
#
#                                                ingredients  \
# 0        ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1        ["1 small jar chipped beef, cut up", "4 boned ...
# 2        ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3        ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4        ["1 c. peanut butter", "3/4 c. graham cracker ...
# ...                                                    ...
# 1643093  ["6 ounces tuna drained", "1 cook egg hard", "...
# 1643094  ["2 tablespoons unsalted butter", "2 tablespoo...
# 1643095  ["1/4 cup white wine vinegar", "1 teaspoon sug...
# 1643096  ["1 egg whites", "1 cup evaporated skim milk",...
# 1643097  ["8 ounces dates cut into small pieces", "1 cu...
#
#                                                 directions  \
# 0        ["In a heavy 2-quart saucepan, mix brown sugar...
# 1        ["Place chipped beef on bottom of baking dish....
# 2        ["In a slow cooker, combine all ingredients. C...
# 3        ["Boil and debone chicken.", "Put bite size pi...
# 4        ["Combine first four ingredients and press in ...
# ...                                                    ...
# 1643093  ["Mix tuna, egg, tomato, red onion and Hellman...
# 1643094  ["In a small sauce pan, melt butter and add fl...
# 1643095  ["For the cucumber salad, mix the vinegar and ...
# 1643096  ["2. Beat egg white with evaporated skim milk....
# 1643097  ["In a small sauce pan place the dates, raisin...
#
#                                                       link    source  \
# 0           www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1          www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2           www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3          www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4          www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
# ...                                                    ...       ...
# 1643093  www.yummly.com/recipe/Tuna-_n-egg-salad-in-pit...  Gathered
# 1643094  www.yummly.com/recipe/Croque-Monsieur-Panini-1...  Gathered
# 1643095  www.yummly.com/recipe/Croque-Monsieur-with-Cuc...  Gathered
# 1643096     www.yummly.com/recipe/Baked-Pork-Chops-1646800  Gathered
# 1643097  www.yummly.com/recipe/Date-Filled-Oatmeal-Cook...  Gathered
#
#                                                        NER
# 0        ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1        ["beef", "chicken breasts", "cream of mushroom...
# 2        ["frozen corn", "cream cheese", "butter", "gar...
# 3        ["chicken", "chicken gravy", "cream of mushroo...
# 4        ["peanut butter", "graham cracker crumbs", "bu...
# ...                                                    ...
# 1643093  ["tuna", "egg hard", "tomatoes", "torn romain ...
# 1643094  ["unsalted butter", "flour", "milk", "black pe...
# 1643095  ["white wine vinegar", "sugar", "olive oil", "...
# 1643096  ["egg whites", "milk", "center", "cornflake cr...
# 1643097  ["dates", "raisins", "sugar", "lemon zest lemo...
#
# [1643098 rows x 7 columns]

# %% [markdown]
# After filtereing out all the recipes not within the "Gathered" subset, we are left with 1,643,098 recipes. In other words, 58,8043 recipes are not within the "Gathered" subset.

# %%
# iterate over all ingredient lists in ingredients column
# return true for those with two or more ingredients
# convert each entry into a numpy array of strings, where each string is an ingredient
ingdt_filter = [np.array(literal_eval(ingredients)).size >= 2 for ingredients in filtered_df.ingredients]
filtered_df = filtered_df[ingdt_filter]
filtered_df
# Out:
#          Unnamed: 0                                title  \
# 0                 0                  No-Bake Nut Cookies
# 1                 1                Jewell Ball'S Chicken
# 2                 2                          Creamy Corn
# 3                 3                        Chicken Funny
# 4                 4                 Reeses Cups(Candy)
# ...             ...                                  ...
# 1643093     1643093           Tuna 'N Egg Salad In Pitas
# 1643094     1643094               Croque Monsieur Panini
# 1643095     1643095  Croque Monsieur With Cucumber Salad
# 1643096     1643096                     Baked Pork Chops
# 1643097     1643097          Date Filled Oatmeal Cookies
#
#                                                ingredients  \
# 0        ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1        ["1 small jar chipped beef, cut up", "4 boned ...
# 2        ["2 (16 oz.) pkg. frozen corn", "1 (8 oz.) pkg...
# 3        ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4        ["1 c. peanut butter", "3/4 c. graham cracker ...
# ...                                                    ...
# 1643093  ["6 ounces tuna drained", "1 cook egg hard", "...
# 1643094  ["2 tablespoons unsalted butter", "2 tablespoo...
# 1643095  ["1/4 cup white wine vinegar", "1 teaspoon sug...
# 1643096  ["1 egg whites", "1 cup evaporated skim milk",...
# 1643097  ["8 ounces dates cut into small pieces", "1 cu...
#
#                                                 directions  \
# 0        ["In a heavy 2-quart saucepan, mix brown sugar...
# 1        ["Place chipped beef on bottom of baking dish....
# 2        ["In a slow cooker, combine all ingredients. C...
# 3        ["Boil and debone chicken.", "Put bite size pi...
# 4        ["Combine first four ingredients and press in ...
# ...                                                    ...
# 1643093  ["Mix tuna, egg, tomato, red onion and Hellman...
# 1643094  ["In a small sauce pan, melt butter and add fl...
# 1643095  ["For the cucumber salad, mix the vinegar and ...
# 1643096  ["2. Beat egg white with evaporated skim milk....
# 1643097  ["In a small sauce pan place the dates, raisin...
#
#                                                       link    source  \
# 0           www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1          www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2           www.cookbooks.com/Recipe-Details.aspx?id=10570  Gathered
# 3          www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4          www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
# ...                                                    ...       ...
# 1643093  www.yummly.com/recipe/Tuna-_n-egg-salad-in-pit...  Gathered
# 1643094  www.yummly.com/recipe/Croque-Monsieur-Panini-1...  Gathered
# 1643095  www.yummly.com/recipe/Croque-Monsieur-with-Cuc...  Gathered
# 1643096     www.yummly.com/recipe/Baked-Pork-Chops-1646800  Gathered
# 1643097  www.yummly.com/recipe/Date-Filled-Oatmeal-Cook...  Gathered
#
#                                                        NER
# 0        ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1        ["beef", "chicken breasts", "cream of mushroom...
# 2        ["frozen corn", "cream cheese", "butter", "gar...
# 3        ["chicken", "chicken gravy", "cream of mushroo...
# 4        ["peanut butter", "graham cracker crumbs", "bu...
# ...                                                    ...
# 1643093  ["tuna", "egg hard", "tomatoes", "torn romain ...
# 1643094  ["unsalted butter", "flour", "milk", "black pe...
# 1643095  ["white wine vinegar", "sugar", "olive oil", "...
# 1643096  ["egg whites", "milk", "center", "cornflake cr...
# 1643097  ["dates", "raisins", "sugar", "lemon zest lemo...
#
# [1640710 rows x 7 columns]

# %% [markdown]
# After filtereing out all the recipes with fewer than 2 ingredients, we are left with 1,640,710 recipes. In other words, 2,388 recipes were filtered out from the gathered subset.

# %%
# analogous to ingdt_filter, removes all entries with fewer than 2 directions
dir_filter_1 = [np.array(literal_eval(directions)).size >= 2 for directions in filtered_df.directions]
filtered_df = filtered_df[dir_filter_1]
filtered_df
# Out:
#          Unnamed: 0                                title  \
# 0                 0                  No-Bake Nut Cookies
# 1                 1                Jewell Ball'S Chicken
# 3                 3                        Chicken Funny
# 4                 4                 Reeses Cups(Candy)
# 5                 5             Cheeseburger Potato Soup
# ...             ...                                  ...
# 1643091     1643091                     Sweet Potato Pie
# 1643094     1643094               Croque Monsieur Panini
# 1643095     1643095  Croque Monsieur With Cucumber Salad
# 1643096     1643096                     Baked Pork Chops
# 1643097     1643097          Date Filled Oatmeal Cookies
#
#                                                ingredients  \
# 0        ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1        ["1 small jar chipped beef, cut up", "4 boned ...
# 3        ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4        ["1 c. peanut butter", "3/4 c. graham cracker ...
# 5        ["6 baking potatoes", "1 lb. of extra lean gro...
# ...                                                    ...
# 1643091  ["1 cup butter or margarine, softened", "1/2 c...
# 1643094  ["2 tablespoons unsalted butter", "2 tablespoo...
# 1643095  ["1/4 cup white wine vinegar", "1 teaspoon sug...
# 1643096  ["1 egg whites", "1 cup evaporated skim milk",...
# 1643097  ["8 ounces dates cut into small pieces", "1 cu...
#
#                                                 directions  \
# 0        ["In a heavy 2-quart saucepan, mix brown sugar...
# 1        ["Place chipped beef on bottom of baking dish....
# 3        ["Boil and debone chicken.", "Put bite size pi...
# 4        ["Combine first four ingredients and press in ...
# 5        ["Wash potatoes; prick several times with a fo...
# ...                                                    ...
# 1643091  ["In a mixing bowl, cream butter and sugar.", ...
# 1643094  ["In a small sauce pan, melt butter and add fl...
# 1643095  ["For the cucumber salad, mix the vinegar and ...
# 1643096  ["2. Beat egg white with evaporated skim milk....
# 1643097  ["In a small sauce pan place the dates, raisin...
#
#                                                       link    source  \
# 0           www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1          www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 3          www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4          www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
# 5           www.cookbooks.com/Recipe-Details.aspx?id=20115  Gathered
# ...                                                    ...       ...
# 1643091     www.yummly.com/recipe/Sweet-Potato-Pie-1674117  Gathered
# 1643094  www.yummly.com/recipe/Croque-Monsieur-Panini-1...  Gathered
# 1643095  www.yummly.com/recipe/Croque-Monsieur-with-Cuc...  Gathered
# 1643096     www.yummly.com/recipe/Baked-Pork-Chops-1646800  Gathered
# 1643097  www.yummly.com/recipe/Date-Filled-Oatmeal-Cook...  Gathered
#
#                                                        NER
# 0        ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1        ["beef", "chicken breasts", "cream of mushroom...
# 3        ["chicken", "chicken gravy", "cream of mushroo...
# 4        ["peanut butter", "graham cracker crumbs", "bu...
# 5        ["baking potatoes", "extra lean ground beef", ...
# ...                                                    ...
# 1643091  ["butter", "sugar", "eggs", "milk", "sweet pot...
# 1643094  ["unsalted butter", "flour", "milk", "black pe...
# 1643095  ["white wine vinegar", "sugar", "olive oil", "...
# 1643096  ["egg whites", "milk", "center", "cornflake cr...
# 1643097  ["dates", "raisins", "sugar", "lemon zest lemo...
#
# [1472742 rows x 7 columns]

# %% [markdown]
# After filtereing out all the recipes with fewer than 2 directions, we are left with 1,472,742 recipes. In other words, 167,968 recipes were further filtered out from the filtered gathered subset.

# %% [markdown]
# To find the number of words in the directions column of each entry, we use `len(re.findall(r'\w+', sentence))` that determines the number of matches in the sentence to the regex `\w+` that consists of the character set `[a-zA-Z0-9_]+`.

# %%
# removes all entries with fewer than 25 words in the directions
dir_filter_2 = [len(re.findall(r'\w+', directions)) >= 25 for directions in filtered_df.directions]
filtered_df = filtered_df[dir_filter_2]
filtered_df
# Out:
#          Unnamed: 0                                title  \
# 0                 0                  No-Bake Nut Cookies
# 1                 1                Jewell Ball'S Chicken
# 3                 3                        Chicken Funny
# 4                 4                 Reeses Cups(Candy)
# 5                 5             Cheeseburger Potato Soup
# ...             ...                                  ...
# 1643091     1643091                     Sweet Potato Pie
# 1643094     1643094               Croque Monsieur Panini
# 1643095     1643095  Croque Monsieur With Cucumber Salad
# 1643096     1643096                     Baked Pork Chops
# 1643097     1643097          Date Filled Oatmeal Cookies
#
#                                                ingredients  \
# 0        ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1        ["1 small jar chipped beef, cut up", "4 boned ...
# 3        ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4        ["1 c. peanut butter", "3/4 c. graham cracker ...
# 5        ["6 baking potatoes", "1 lb. of extra lean gro...
# ...                                                    ...
# 1643091  ["1 cup butter or margarine, softened", "1/2 c...
# 1643094  ["2 tablespoons unsalted butter", "2 tablespoo...
# 1643095  ["1/4 cup white wine vinegar", "1 teaspoon sug...
# 1643096  ["1 egg whites", "1 cup evaporated skim milk",...
# 1643097  ["8 ounces dates cut into small pieces", "1 cu...
#
#                                                 directions  \
# 0        ["In a heavy 2-quart saucepan, mix brown sugar...
# 1        ["Place chipped beef on bottom of baking dish....
# 3        ["Boil and debone chicken.", "Put bite size pi...
# 4        ["Combine first four ingredients and press in ...
# 5        ["Wash potatoes; prick several times with a fo...
# ...                                                    ...
# 1643091  ["In a mixing bowl, cream butter and sugar.", ...
# 1643094  ["In a small sauce pan, melt butter and add fl...
# 1643095  ["For the cucumber salad, mix the vinegar and ...
# 1643096  ["2. Beat egg white with evaporated skim milk....
# 1643097  ["In a small sauce pan place the dates, raisin...
#
#                                                       link    source  \
# 0           www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1          www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 3          www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4          www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
# 5           www.cookbooks.com/Recipe-Details.aspx?id=20115  Gathered
# ...                                                    ...       ...
# 1643091     www.yummly.com/recipe/Sweet-Potato-Pie-1674117  Gathered
# 1643094  www.yummly.com/recipe/Croque-Monsieur-Panini-1...  Gathered
# 1643095  www.yummly.com/recipe/Croque-Monsieur-with-Cuc...  Gathered
# 1643096     www.yummly.com/recipe/Baked-Pork-Chops-1646800  Gathered
# 1643097  www.yummly.com/recipe/Date-Filled-Oatmeal-Cook...  Gathered
#
#                                                        NER
# 0        ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1        ["beef", "chicken breasts", "cream of mushroom...
# 3        ["chicken", "chicken gravy", "cream of mushroo...
# 4        ["peanut butter", "graham cracker crumbs", "bu...
# 5        ["baking potatoes", "extra lean ground beef", ...
# ...                                                    ...
# 1643091  ["butter", "sugar", "eggs", "milk", "sweet pot...
# 1643094  ["unsalted butter", "flour", "milk", "black pe...
# 1643095  ["white wine vinegar", "sugar", "olive oil", "...
# 1643096  ["egg whites", "milk", "center", "cornflake cr...
# 1643097  ["dates", "raisins", "sugar", "lemon zest lemo...
#
# [1312534 rows x 7 columns]

# %% [markdown]
# After filtereing out all the recipes with fewer than 25 words in their directions, we are left with 1,312,534 recipes. In other words, 160,208 recipes were further filtered out from the filtered gathered subset.

# %%
# instead of returning True when the string contains "step"
# it will return False instead due to "~" sign, so that all those entries can be filtered out
# case=False so that the search is not case sensitive
step_filter = ~filtered_df['directions'].str.contains("step", case=False)
filtered_df = filtered_df[step_filter]
filtered_df
# Out:
#          Unnamed: 0                                title  \
# 0                 0                  No-Bake Nut Cookies
# 1                 1                Jewell Ball'S Chicken
# 3                 3                        Chicken Funny
# 4                 4                 Reeses Cups(Candy)
# 5                 5             Cheeseburger Potato Soup
# ...             ...                                  ...
# 1643091     1643091                     Sweet Potato Pie
# 1643094     1643094               Croque Monsieur Panini
# 1643095     1643095  Croque Monsieur With Cucumber Salad
# 1643096     1643096                     Baked Pork Chops
# 1643097     1643097          Date Filled Oatmeal Cookies
#
#                                                ingredients  \
# 0        ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1        ["1 small jar chipped beef, cut up", "4 boned ...
# 3        ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4        ["1 c. peanut butter", "3/4 c. graham cracker ...
# 5        ["6 baking potatoes", "1 lb. of extra lean gro...
# ...                                                    ...
# 1643091  ["1 cup butter or margarine, softened", "1/2 c...
# 1643094  ["2 tablespoons unsalted butter", "2 tablespoo...
# 1643095  ["1/4 cup white wine vinegar", "1 teaspoon sug...
# 1643096  ["1 egg whites", "1 cup evaporated skim milk",...
# 1643097  ["8 ounces dates cut into small pieces", "1 cu...
#
#                                                 directions  \
# 0        ["In a heavy 2-quart saucepan, mix brown sugar...
# 1        ["Place chipped beef on bottom of baking dish....
# 3        ["Boil and debone chicken.", "Put bite size pi...
# 4        ["Combine first four ingredients and press in ...
# 5        ["Wash potatoes; prick several times with a fo...
# ...                                                    ...
# 1643091  ["In a mixing bowl, cream butter and sugar.", ...
# 1643094  ["In a small sauce pan, melt butter and add fl...
# 1643095  ["For the cucumber salad, mix the vinegar and ...
# 1643096  ["2. Beat egg white with evaporated skim milk....
# 1643097  ["In a small sauce pan place the dates, raisin...
#
#                                                       link    source  \
# 0           www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1          www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 3          www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4          www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
# 5           www.cookbooks.com/Recipe-Details.aspx?id=20115  Gathered
# ...                                                    ...       ...
# 1643091     www.yummly.com/recipe/Sweet-Potato-Pie-1674117  Gathered
# 1643094  www.yummly.com/recipe/Croque-Monsieur-Panini-1...  Gathered
# 1643095  www.yummly.com/recipe/Croque-Monsieur-with-Cuc...  Gathered
# 1643096     www.yummly.com/recipe/Baked-Pork-Chops-1646800  Gathered
# 1643097  www.yummly.com/recipe/Date-Filled-Oatmeal-Cook...  Gathered
#
#                                                        NER
# 0        ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1        ["beef", "chicken breasts", "cream of mushroom...
# 3        ["chicken", "chicken gravy", "cream of mushroo...
# 4        ["peanut butter", "graham cracker crumbs", "bu...
# 5        ["baking potatoes", "extra lean ground beef", ...
# ...                                                    ...
# 1643091  ["butter", "sugar", "eggs", "milk", "sweet pot...
# 1643094  ["unsalted butter", "flour", "milk", "black pe...
# 1643095  ["white wine vinegar", "sugar", "olive oil", "...
# 1643096  ["egg whites", "milk", "center", "cornflake cr...
# 1643097  ["dates", "raisins", "sugar", "lemon zest lemo...
#
# [1301548 rows x 7 columns]

# %% [markdown]
# After filtereing out all the recipes with the word "step" in their directions, we are left with 1,301,548 recipes. In other words, 10,986 recipes were further filtered out from the filtered gathered subset.

# %%
# analogous to dir_filter_2
title_filter = [len(re.findall(r'\w+', title)) >= 2 for title in filtered_df.title]
filtered_df = filtered_df[title_filter]
filtered_df
# Out:
#          Unnamed: 0                                title  \
# 0                 0                  No-Bake Nut Cookies
# 1                 1                Jewell Ball'S Chicken
# 3                 3                        Chicken Funny
# 4                 4                 Reeses Cups(Candy)
# 5                 5             Cheeseburger Potato Soup
# ...             ...                                  ...
# 1643091     1643091                     Sweet Potato Pie
# 1643094     1643094               Croque Monsieur Panini
# 1643095     1643095  Croque Monsieur With Cucumber Salad
# 1643096     1643096                     Baked Pork Chops
# 1643097     1643097          Date Filled Oatmeal Cookies
#
#                                                ingredients  \
# 0        ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1        ["1 small jar chipped beef, cut up", "4 boned ...
# 3        ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4        ["1 c. peanut butter", "3/4 c. graham cracker ...
# 5        ["6 baking potatoes", "1 lb. of extra lean gro...
# ...                                                    ...
# 1643091  ["1 cup butter or margarine, softened", "1/2 c...
# 1643094  ["2 tablespoons unsalted butter", "2 tablespoo...
# 1643095  ["1/4 cup white wine vinegar", "1 teaspoon sug...
# 1643096  ["1 egg whites", "1 cup evaporated skim milk",...
# 1643097  ["8 ounces dates cut into small pieces", "1 cu...
#
#                                                 directions  \
# 0        ["In a heavy 2-quart saucepan, mix brown sugar...
# 1        ["Place chipped beef on bottom of baking dish....
# 3        ["Boil and debone chicken.", "Put bite size pi...
# 4        ["Combine first four ingredients and press in ...
# 5        ["Wash potatoes; prick several times with a fo...
# ...                                                    ...
# 1643091  ["In a mixing bowl, cream butter and sugar.", ...
# 1643094  ["In a small sauce pan, melt butter and add fl...
# 1643095  ["For the cucumber salad, mix the vinegar and ...
# 1643096  ["2. Beat egg white with evaporated skim milk....
# 1643097  ["In a small sauce pan place the dates, raisin...
#
#                                                       link    source  \
# 0           www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1          www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 3          www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4          www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
# 5           www.cookbooks.com/Recipe-Details.aspx?id=20115  Gathered
# ...                                                    ...       ...
# 1643091     www.yummly.com/recipe/Sweet-Potato-Pie-1674117  Gathered
# 1643094  www.yummly.com/recipe/Croque-Monsieur-Panini-1...  Gathered
# 1643095  www.yummly.com/recipe/Croque-Monsieur-with-Cuc...  Gathered
# 1643096     www.yummly.com/recipe/Baked-Pork-Chops-1646800  Gathered
# 1643097  www.yummly.com/recipe/Date-Filled-Oatmeal-Cook...  Gathered
#
#                                                        NER
# 0        ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1        ["beef", "chicken breasts", "cream of mushroom...
# 3        ["chicken", "chicken gravy", "cream of mushroo...
# 4        ["peanut butter", "graham cracker crumbs", "bu...
# 5        ["baking potatoes", "extra lean ground beef", ...
# ...                                                    ...
# 1643091  ["butter", "sugar", "eggs", "milk", "sweet pot...
# 1643094  ["unsalted butter", "flour", "milk", "black pe...
# 1643095  ["white wine vinegar", "sugar", "olive oil", "...
# 1643096  ["egg whites", "milk", "center", "cornflake cr...
# 1643097  ["dates", "raisins", "sugar", "lemon zest lemo...
#
# [1276159 rows x 7 columns]

# %% [markdown]
# After filtereing out all the recipes with fewer than 2 words in their titles, we are left with 1,276,159 recipes. In other words, 25,389 recipes were further filtered out from the filtered gathered subset.

# %%
# analogous to step_filter
mix_all_filter = ~filtered_df['directions'].str.contains("mix all", case=False)
filtered_df = filtered_df[mix_all_filter]
filtered_df
# Out:
#          Unnamed: 0                                title  \
# 0                 0                  No-Bake Nut Cookies
# 1                 1                Jewell Ball'S Chicken
# 3                 3                        Chicken Funny
# 4                 4                 Reeses Cups(Candy)
# 5                 5             Cheeseburger Potato Soup
# ...             ...                                  ...
# 1643091     1643091                     Sweet Potato Pie
# 1643094     1643094               Croque Monsieur Panini
# 1643095     1643095  Croque Monsieur With Cucumber Salad
# 1643096     1643096                     Baked Pork Chops
# 1643097     1643097          Date Filled Oatmeal Cookies
#
#                                                ingredients  \
# 0        ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1        ["1 small jar chipped beef, cut up", "4 boned ...
# 3        ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 4        ["1 c. peanut butter", "3/4 c. graham cracker ...
# 5        ["6 baking potatoes", "1 lb. of extra lean gro...
# ...                                                    ...
# 1643091  ["1 cup butter or margarine, softened", "1/2 c...
# 1643094  ["2 tablespoons unsalted butter", "2 tablespoo...
# 1643095  ["1/4 cup white wine vinegar", "1 teaspoon sug...
# 1643096  ["1 egg whites", "1 cup evaporated skim milk",...
# 1643097  ["8 ounces dates cut into small pieces", "1 cu...
#
#                                                 directions  \
# 0        ["In a heavy 2-quart saucepan, mix brown sugar...
# 1        ["Place chipped beef on bottom of baking dish....
# 3        ["Boil and debone chicken.", "Put bite size pi...
# 4        ["Combine first four ingredients and press in ...
# 5        ["Wash potatoes; prick several times with a fo...
# ...                                                    ...
# 1643091  ["In a mixing bowl, cream butter and sugar.", ...
# 1643094  ["In a small sauce pan, melt butter and add fl...
# 1643095  ["For the cucumber salad, mix the vinegar and ...
# 1643096  ["2. Beat egg white with evaporated skim milk....
# 1643097  ["In a small sauce pan place the dates, raisin...
#
#                                                       link    source  \
# 0           www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1          www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 3          www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 4          www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
# 5           www.cookbooks.com/Recipe-Details.aspx?id=20115  Gathered
# ...                                                    ...       ...
# 1643091     www.yummly.com/recipe/Sweet-Potato-Pie-1674117  Gathered
# 1643094  www.yummly.com/recipe/Croque-Monsieur-Panini-1...  Gathered
# 1643095  www.yummly.com/recipe/Croque-Monsieur-with-Cuc...  Gathered
# 1643096     www.yummly.com/recipe/Baked-Pork-Chops-1646800  Gathered
# 1643097  www.yummly.com/recipe/Date-Filled-Oatmeal-Cook...  Gathered
#
#                                                        NER
# 0        ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1        ["beef", "chicken breasts", "cream of mushroom...
# 3        ["chicken", "chicken gravy", "cream of mushroo...
# 4        ["peanut butter", "graham cracker crumbs", "bu...
# 5        ["baking potatoes", "extra lean ground beef", ...
# ...                                                    ...
# 1643091  ["butter", "sugar", "eggs", "milk", "sweet pot...
# 1643094  ["unsalted butter", "flour", "milk", "black pe...
# 1643095  ["white wine vinegar", "sugar", "olive oil", "...
# 1643096  ["egg whites", "milk", "center", "cornflake cr...
# 1643097  ["dates", "raisins", "sugar", "lemon zest lemo...
#
# [1234476 rows x 7 columns]

# %% [markdown]
# After filtereing out all the recipes with the phrase "mix all" in their directions, we are left with 1,234,476 recipes. In other words, 41,683 recipes were further filtered out from the filtered gathered subset. This should be more than enough to train the ML-Chef model.

# %% [markdown]
# Now, clean up the dataframe by removing the unnamed first column (not needed due to the indices present that help us navigate the dataframe) and resetting the indices so that they are consecutive numbers.

# %%
# delete first column and set it in place
filtered_df.drop(columns=filtered_df.columns[0], inplace=True)

# reset index
filtered_df = filtered_df.reset_index(drop=True)
filtered_df
# Out:
# <ipython-input-10-efbc3633ec30>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df.drop(columns=filtered_df.columns[0], inplace=True)
#                                        title  \
# 0                        No-Bake Nut Cookies
# 1                      Jewell Ball'S Chicken
# 2                              Chicken Funny
# 3                       Reeses Cups(Candy)
# 4                   Cheeseburger Potato Soup
# ...                                      ...
# 1234471                     Sweet Potato Pie
# 1234472               Croque Monsieur Panini
# 1234473  Croque Monsieur With Cucumber Salad
# 1234474                     Baked Pork Chops
# 1234475          Date Filled Oatmeal Cookies
#
#                                                ingredients  \
# 0        ["1 c. firmly packed brown sugar", "1/2 c. eva...
# 1        ["1 small jar chipped beef, cut up", "4 boned ...
# 2        ["1 large whole chicken", "2 (10 1/2 oz.) cans...
# 3        ["1 c. peanut butter", "3/4 c. graham cracker ...
# 4        ["6 baking potatoes", "1 lb. of extra lean gro...
# ...                                                    ...
# 1234471  ["1 cup butter or margarine, softened", "1/2 c...
# 1234472  ["2 tablespoons unsalted butter", "2 tablespoo...
# 1234473  ["1/4 cup white wine vinegar", "1 teaspoon sug...
# 1234474  ["1 egg whites", "1 cup evaporated skim milk",...
# 1234475  ["8 ounces dates cut into small pieces", "1 cu...
#
#                                                 directions  \
# 0        ["In a heavy 2-quart saucepan, mix brown sugar...
# 1        ["Place chipped beef on bottom of baking dish....
# 2        ["Boil and debone chicken.", "Put bite size pi...
# 3        ["Combine first four ingredients and press in ...
# 4        ["Wash potatoes; prick several times with a fo...
# ...                                                    ...
# 1234471  ["In a mixing bowl, cream butter and sugar.", ...
# 1234472  ["In a small sauce pan, melt butter and add fl...
# 1234473  ["For the cucumber salad, mix the vinegar and ...
# 1234474  ["2. Beat egg white with evaporated skim milk....
# 1234475  ["In a small sauce pan place the dates, raisin...
#
#                                                       link    source  \
# 0           www.cookbooks.com/Recipe-Details.aspx?id=44874  Gathered
# 1          www.cookbooks.com/Recipe-Details.aspx?id=699419  Gathered
# 2          www.cookbooks.com/Recipe-Details.aspx?id=897570  Gathered
# 3          www.cookbooks.com/Recipe-Details.aspx?id=659239  Gathered
# 4           www.cookbooks.com/Recipe-Details.aspx?id=20115  Gathered
# ...                                                    ...       ...
# 1234471     www.yummly.com/recipe/Sweet-Potato-Pie-1674117  Gathered
# 1234472  www.yummly.com/recipe/Croque-Monsieur-Panini-1...  Gathered
# 1234473  www.yummly.com/recipe/Croque-Monsieur-with-Cuc...  Gathered
# 1234474     www.yummly.com/recipe/Baked-Pork-Chops-1646800  Gathered
# 1234475  www.yummly.com/recipe/Date-Filled-Oatmeal-Cook...  Gathered
#
#                                                        NER
# 0        ["brown sugar", "milk", "vanilla", "nuts", "bu...
# 1        ["beef", "chicken breasts", "cream of mushroom...
# 2        ["chicken", "chicken gravy", "cream of mushroo...
# 3        ["peanut butter", "graham cracker crumbs", "bu...
# 4        ["baking potatoes", "extra lean ground beef", ...
# ...                                                    ...
# 1234471  ["butter", "sugar", "eggs", "milk", "sweet pot...
# 1234472  ["unsalted butter", "flour", "milk", "black pe...
# 1234473  ["white wine vinegar", "sugar", "olive oil", "...
# 1234474  ["egg whites", "milk", "center", "cornflake cr...
# 1234475  ["dates", "raisins", "sugar", "lemon zest lemo...
#
# [1234476 rows x 6 columns]

# %% [markdown]
# Save the filtered dataframe as a CSV file to avoid having to go through the filtering process everytime when accessing the training data, as it is time consuming.

# %%
filtered_dataset_destination = '/content/drive/MyDrive/recipe_data/filtered_dataset.csv'
filtered_df.to_csv(filtered_dataset_destination, index = None)
